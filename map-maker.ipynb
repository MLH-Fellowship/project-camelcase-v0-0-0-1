# %%
# Use this file to generate a map using folium

import folium
import random

# %%
#update the location where you want your map to open to
m = folium.Map(location=[40.730610, -73.935242], zoom_start=3, max_zoom=14, min_zoom=3)

# %%
#update tooltip to change what showes when user hover over a marker
tooltip = "Click me"
symbols = ['😜', '😏', '👀', '😛', '🤫', '😳', '🤭', '🙊', '😅', '😉', '🤘', '🤗', '😄', '👨🏽‍💻', '👋🏾', '🤔']

gen_tooltip = lambda : tooltip + f' {symbols[random.randint(-1, len(symbols) - 1)]}'

#place as many markers as you want
folium.Marker(
    [18.483402, -69.929611], popup="<i>Dominican Republic</i>", tooltip=gen_tooltip()
).add_to(m)
folium.Marker(
    [40.768742, -73.965179], popup="<i>Hunter College</i>", tooltip=gen_tooltip()
).add_to(m)

folium.Marker(
    [40.714330, -74.015160], popup="<i>North Cove Marina</i>", tooltip=gen_tooltip()
).add_to(m) 

folium.Marker(
    [40.752171,-74.008011], popup="<i>Hudson River Community Sailing Chelsea</i>", tooltip=gen_tooltip()
).add_to(m)

folium.Marker(
    [40.868420,-73.930800], popup="<i>Hudson River Community Sailing Inwood</i>", tooltip=gen_tooltip()
).add_to(m)

folium.Marker(
    [40.829269,-73.927933], popup="<i>Yankee Stadium</i>", tooltip=gen_tooltip()
).add_to(m) 


folium.Marker(
    [40.602344,-75.471807], popup="<i>Allentown</i>", tooltip=gen_tooltip()
).add_to(m) 

folium.Marker(
    [39.9527237,-75.1635262], popup="<i>Philadelphia</i>", tooltip=gen_tooltip()
).add_to(m) 

folium.Marker(
    [40.91177056572849,-73.12281575078127], popup="<i>Stony Brook University</i>", tooltip=gen_tooltip()
).add_to(m) 


folium.Marker(
    [40.69034506729761,-73.9811226355469], popup="<i>Brooklyn</i>", tooltip=gen_tooltip()
).add_to(m) #40.602344,-75.471807

folium.Marker(
    [40.567098788284135,-73.88327565068361], popup="<i>Rockaway</i>", tooltip=gen_tooltip()
).add_to(m) 



folium.Marker(
    [40.979712960138066, -73.6819168555176], popup="<i>City of Rye</i>", tooltip=gen_tooltip()
).add_to(m)



folium.Marker(
    [41.460555380559654, -73.65788426274416], popup="<i>Lake Carmel</i>", tooltip=gen_tooltip()
).add_to(m)

folium.Marker(
    [40.84320455568779,-73.78479873891601], popup="<i>City Island</i>", tooltip=gen_tooltip()
).add_to(m)

# %%
#run this to show what your map looks like
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#run this to save your map can be shown
m.save("./app/templates/maps/dario-places-visited.html")
